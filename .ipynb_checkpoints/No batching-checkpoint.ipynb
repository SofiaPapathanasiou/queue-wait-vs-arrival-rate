# %% [markdown]
# ## Experiment Set 1: No batching
#
# No batching, varying request rates, poisson arrivals, asynchronous calls
#
# Current config:
# ``` bash
# name: "food_classifier_onnx"
# backend: "onnxruntime"
# max_batch_size: 1
# input [
#   {
#     name: "input"  # has to match ONNX model's input name
#     data_type: TYPE_FP32
#     dims: [3, 224, 224]  # has to match ONNX input shape
#   }
# ]
# output [
#   {
#     name: "output"  # has to match ONNX model output name
#     data_type: TYPE_FP32  # output is a list of probabilities
#     dims: [11]  #
#   }
# ]
#   instance_group [
#     {
#       count: 1
#       kind: KIND_GPU
#       gpus: [ 0 ]
#     }
# ]
# ```

# %%
# runs inside the Jupyter container on node-serve-system
perf_analyzer -u triton_server:8000 -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 --request-rate-range 80 --async --request-distribution constant
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Using uniform distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 80 inference requests per second
#   Client:
#     Request count: 1463
#     Throughput: 79.9214 infer/sec
#     Avg latency: 9340 usec (standard deviation 1370 usec)
#     p50 latency: 9282 usec
#     p90 latency: 9671 usec
#     p95 latency: 9887 usec
#     p99 latency: 10171 usec
#     Avg HTTP time: 9297 usec (send/recv 566 usec + response wait 8731 usec)
#   Server:
#     Inference count: 1463
#     Execution count: 1463
#     Successful request count: 1463
#     Avg request latency: 6997 usec (overhead 39 usec + queue 74 usec + compute input 153 usec + compute infer 6707 usec + compute output 22 usec)
# Inferences/Second vs. Client Average Batch Latency
# ...

# %%
# runs inside the Jupyter container on node-serve-system
perf_analyzer -u triton_server:8000 -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 --request-rate-range 100 --async --request-distribution constant
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Using uniform distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 100 inference requests per second
#   Client:
#     Request count: 1843
#     Throughput: 100.006 infer/sec
#     Avg latency: 8352 usec (standard deviation 1508 usec)
#     p50 latency: 8349 usec
#     p90 latency: 8992 usec
#     p95 latency: 9118 usec
#     p99 latency: 9321 usec
#     Avg HTTP time: 8285 usec (send/recv 573 usec + response wait 7712 usec)
#   Server:
#     Inference count: 1843
#     Execution count: 1843
#     Successful request count: 1843
#     Avg request latency: 6106 usec (overhead 37 usec + queue 57 usec + compute input 144 usec + compute infer 5845 usec + compute output 22 usec)
# Inferences/Second vs. Client Average Batch Latency
# ...

# %%
# runs inside the Jupyter container on node-serve-system
perf_analyzer -u triton_server:8000 -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 --request-rate-range 120 --async --request-distribution constant
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Using uniform distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 120 inference requests per second
#   Client:
#     Request count: 2211
#     Throughput: 119.936 infer/sec
#     Avg latency: 7994 usec (standard deviation 1803 usec)
#     p50 latency: 7985 usec
#     p90 latency: 8262 usec
#     p95 latency: 8321 usec
#     p99 latency: 10545 usec
#     Avg HTTP time: 7948 usec (send/recv 705 usec + response wait 7243 usec)
#   Server:
#     Inference count: 2211
#     Execution count: 2211
#     Successful request count: 2211
#     Avg request latency: 5557 usec (overhead 33 usec + queue 102 usec + compute input 136 usec + compute infer 5267 usec + compute output 19 usec)
# Inferences/Second vs. Client Average Batch Latency
# ...

# %%
# runs inside the Jupyter container on node-serve-system
perf_analyzer -u triton_server:8000 -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 --request-rate-range 140 --async --request-distribution constant
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Using uniform distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 140 inference requests per second
#   Client:
#     Request count: 2588
#     Throughput: 139.919 infer/sec
#     Avg latency: 7262 usec (standard deviation 1605 usec)
#     p50 latency: 7201 usec
#     p90 latency: 7538 usec
#     p95 latency: 7684 usec
#     p99 latency: 12232 usec
#     Avg HTTP time: 7213 usec (send/recv 716 usec + response wait 6497 usec)
#   Server:
#     Inference count: 2588
#     Execution count: 2588
#     Successful request count: 2588
#     Avg request latency: 4932 usec (overhead 30 usec + queue 136 usec + compute input 134 usec + compute infer 4613 usec + compute output 18 usec)
# Inferences/Second vs. Client Average Batch Latency
# ...

# %%
# runs inside the Jupyter container on node-serve-system
perf_analyzer -u triton_server:8000 -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 --request-rate-range 160 --async --request-distribution constant
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Using uniform distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 160 inference requests per second
#   Client:
#     Request count: 2967
#     Throughput: 159.928 infer/sec
#     Avg latency: 6715 usec (standard deviation 2518 usec)
#     p50 latency: 6459 usec
#     p90 latency: 7031 usec
#     p95 latency: 7143 usec
#     p99 latency: 11677 usec
#     Avg HTTP time: 6637 usec (send/recv 607 usec + response wait 6030 usec)
#   Server:
#     Inference count: 2967
#     Execution count: 2967
#     Successful request count: 2967
#     Avg request latency: 4348 usec (overhead 27 usec + queue 131 usec + compute input 120 usec + compute infer 4053 usec + compute output 16 usec)
# Inferences/Second vs. Client Average Batch Latency
# ...

# %%
# runs inside the Jupyter container on node-serve-system
perf_analyzer -u triton_server:8000 -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 --request-rate-range 180 --async --request-distribution constant
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Using uniform distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 180 inference requests per second
#   Client:
#     Request count: 3344
#     Throughput: 179.881 infer/sec
#     Avg latency: 6394 usec (standard deviation 2147 usec)
#     p50 latency: 6216 usec
#     p90 latency: 6569 usec
#     p95 latency: 7261 usec
#     p99 latency: 13755 usec
#     Avg HTTP time: 6352 usec (send/recv 672 usec + response wait 5680 usec)
#   Server:
#     Inference count: 3345
#     Execution count: 3345
#     Successful request count: 3345
#     Avg request latency: 3975 usec (overhead 23 usec + queue 193 usec + compute input 109 usec + compute infer 3634 usec + compute output 14 usec)
# Inferences/Second vs. Client Average Batch Latency
# ...

# %%
# runs inside the Jupyter container on node-serve-system
perf_analyzer -u triton_server:8000 -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 --request-rate-range 200 --async --request-distribution constant
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Using uniform distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 200 inference requests per second
#   Client:
#     Request count: 3889
#     Avg send request rate: 198.56 infer/sec
#     [WARNING] Perf Analyzer was not able to keep up with the desired request rate. 1.52% of the requests were delayed.
#     Throughput: 199.98 infer/sec
#     Avg latency: 5884 usec (standard deviation 5068 usec)
#     p50 latency: 5247 usec
#     p90 latency: 6124 usec
#     p95 latency: 6773 usec
#     p99 latency: 24582 usec
#     Avg HTTP time: 5756 usec (send/recv 519 usec + response wait 5237 usec)
#   Server:
#     Inference count: 3890
#     Execution count: 3890
#     Successful request count: 3890
# ...

# %%
# runs inside the Jupyter container on node-serve-system
perf_analyzer -u triton_server:8000 -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 --request-rate-range 220 --async --request-distribution constant
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Using uniform distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 220 inference requests per second
#   Client:
#     Request count: 4139
#     Throughput: 219.965 infer/sec
#     Avg latency: 5323 usec (standard deviation 3045 usec)
#     p50 latency: 4991 usec
#     p90 latency: 5261 usec
#     p95 latency: 5703 usec
#     p99 latency: 15080 usec
#     Avg HTTP time: 5265 usec (send/recv 334 usec + response wait 4931 usec)
#   Server:
#     Inference count: 4140
#     Execution count: 4140
#     Successful request count: 4140
#     Avg request latency: 3217 usec (overhead 19 usec + queue 168 usec + compute input 99 usec + compute infer 2918 usec + compute output 11 usec)
# Inferences/Second vs. Client Average Batch Latency
# ...

# %%
# runs inside the Jupyter container on node-serve-system
perf_analyzer -u triton_server:8000 -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 --request-rate-range 240 --async --request-distribution constant
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Using uniform distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 240 inference requests per second
# ...
#   Client:
#     Request count: 4685
#     Avg send request rate: 234.91 infer/sec
#     [WARNING] Perf Analyzer was not able to keep up with the desired request rate. 1.77% of the requests were delayed.
#     Throughput: 240.01 infer/sec
#     Avg latency: 6036 usec (standard deviation 5534 usec)
#     p50 latency: 5072 usec
#     p90 latency: 5786 usec
#     p95 latency: 9277 usec
#     p99 latency: 32862 usec
#     Avg HTTP time: 5934 usec (send/recv 417 usec + response wait 5517 usec)
#   Server:
#     Inference count: 4684
#     Execution count: 4684
#     Successful request count: 4684
# ...

# %%
# runs inside the Jupyter container on node-serve-system
perf_analyzer -u triton_server:8000 -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 --request-rate-range 260 --async --request-distribution constant
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Using uniform distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 260 inference requests per second
# ...
#   Client:
#     Request count: 4946
#     Avg send request rate: 255.96 infer/sec
#     [WARNING] Perf Analyzer was not able to keep up with the desired request rate. 1.11% of the requests were delayed.
#     Throughput: 259.99 infer/sec
#     Avg latency: 5757 usec (standard deviation 5172 usec)
#     p50 latency: 5055 usec
#     p90 latency: 5573 usec
#     p95 latency: 5984 usec
#     p99 latency: 27976 usec
#     Avg HTTP time: 5622 usec (send/recv 358 usec + response wait 5264 usec)
#   Server:
#     Inference count: 4946
#     Execution count: 4946
#     Successful request count: 4946
# ...

# %%
# runs inside the Jupyter container on node-serve-system
perf_analyzer -u triton_server:8000 -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 --request-rate-range 280 --async --request-distribution constant
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Using uniform distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 280 inference requests per second
#   Client:
#     Request count: 5588
#     Avg send request rate: 281.03 infer/sec
#     [WARNING] Perf Analyzer was not able to keep up with the desired request rate. 2.34% of the requests were delayed.
#     Throughput: 280.02 infer/sec
#     Avg latency: 7390 usec (standard deviation 9069 usec)
#     p50 latency: 4961 usec
#     p90 latency: 8402 usec
#     p95 latency: 28604 usec
#     p99 latency: 46119 usec
#     Avg HTTP time: 7274 usec (send/recv 363 usec + response wait 6911 usec)
#   Server:
#     Inference count: 5587
#     Execution count: 5587
#     Successful request count: 5587
# ...

# %%
# runs inside the Jupyter container on node-serve-system
perf_analyzer -u triton_server:8000 -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 --request-rate-range 300 --async --request-distribution constant
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Using uniform distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 300 inference requests per second
# ...
#   Client:
#     Request count: 6029
#     Avg send request rate: 297.81 infer/sec
#     [WARNING] Perf Analyzer was not able to keep up with the desired request rate. 2.52% of the requests were delayed.
#     Throughput: 300.04 infer/sec
#     Avg latency: 8609 usec (standard deviation 10783 usec)
#     p50 latency: 5066 usec
#     p90 latency: 19933 usec
#     p95 latency: 35103 usec
#     p99 latency: 52691 usec
#     Avg HTTP time: 8505 usec (send/recv 406 usec + response wait 8099 usec)
#   Server:
#     Inference count: 6028
#     Execution count: 6028
#     Successful request count: 6029
# ...

# %%
# runs inside the Jupyter container on node-serve-system
perf_analyzer -u triton_server:8000 -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 --request-rate-range 320 --async --request-distribution constant
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Using uniform distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 320 inference requests per second
# ...
#   Client:
#     Request count: 6543
#     Avg send request rate: 319.15 infer/sec
#     [WARNING] Perf Analyzer was not able to keep up with the desired request rate. 2.97% of the requests were delayed.
#     Throughput: 319.99 infer/sec
#     Avg latency: 14858 usec (standard deviation 18119 usec)
#     p50 latency: 5576 usec
#     p90 latency: 43377 usec
#     p95 latency: 51571 usec
#     p99 latency: 68854 usec
#     Avg HTTP time: 14634 usec (send/recv 478 usec + response wait 14156 usec)
#   Server:
#     Inference count: 6542
#     Execution count: 6542
#     Successful request count: 6542
# ...

# %%
# runs inside the Jupyter container on node-serve-system
perf_analyzer -u triton_server:8000 -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 --request-rate-range 340 --async --request-distribution constant
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Using uniform distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 340 inference requests per second
# ...
#   Client:
#     Request count: 6536
#     Avg send request rate: 332.77 infer/sec
#     [WARNING] Perf Analyzer was not able to keep up with the desired request rate. 2.37% of the requests were delayed.
#     Throughput: 329.45 infer/sec
#     Avg latency: 1681794 usec (standard deviation 41599 usec)
#     p50 latency: 1686835 usec
#     p90 latency: 1927755 usec
#     p95 latency: 1961749 usec
#     p99 latency: 1982344 usec
#     Avg HTTP time: 1681493 usec (send/recv 1800 usec + response wait 1679693 usec)
#   Server:
#     Inference count: 6537
#     Execution count: 6537
#     Successful request count: 6537
# ...

# %%
# runs inside the Jupyter container on node-serve-system
perf_analyzer -u triton_server:8000 -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 --request-rate-range 360 --async --request-distribution constant
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Using uniform distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 360 inference requests per second

# %%
# runs inside the Jupyter container on node-serve-system
perf_analyzer -u triton_server:8000 -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 --request-rate-range 380 --async --request-distribution constant
