# %% [markdown]
# ## Experiment Set 3: Dynamic Batching, max batch size 8
#
# Dynamic batching, poisson arrivals, asynchronous calls, varying arrival rates
#
# To edit the model configuration:
#
# ``` bash
# # runs on node-serve-system
# nano ~/serve-system-chi/models/food_classifier_onnx/config.pbtxt
# ```
#
# Current config:
#
# ``` bash
# name: "food_classifier_onnx"
# backend: "onnxruntime"
# max_batch_size: 8
# input [
#   {
#     name: "input"  # has to match ONNX model's input name
#     data_type: TYPE_FP32
#     dims: [3, 224, 224]  # has to match ONNX input shape
#   }
# ]
# output [
#   {
#     name: "output"  # has to match ONNX model output name
#     data_type: TYPE_FP32  # output is a list of probabilities
#     dims: [11]  #
#   }
# ]
#   instance_group [
#     {
#       count: 1
#       kind: KIND_GPU
#       gpus: [ 0 ]
#     }
# ]
#
# dynamic_batching {
#     preferred_batch_size: [8]
#     max_queue_delay_microseconds: 100
# }
#
# ```
# Save the file (use Ctrl+O then Enter, then Ctrl+X).
#
# Re-build the container image with this change:
#
# ``` bash
# # runs on node-serve-system
# docker compose -f ~/serve-system-chi/docker/docker-compose-triton.yaml build triton_server
# ```
#
# and then bring the server back up:
#
# ``` bash
# # runs on node-serve-system
# docker compose -f ~/serve-system-chi/docker/docker-compose-triton.yaml up triton_server --force-recreate -d
# ```
#
# and use
#
# ``` bash
# # runs on node-serve-system
# docker logs triton_server
# ```
#
# to make sure the server comes up and is ready.
#
# Before we benchmark this service again, let’s get some pre-benchmark stats about how many requests have been served, broken down by batch size. (If you’ve just restarted the server, it would be zero!)

# %%
# runs inside the Jupyter container on node-serve-system
perf_analyzer -u triton_server:8000 -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 --request-rate-range 20:100:20 --async --request-distribution poisson | tee /home/jovyan/work/batch_8_results/batch_8_20-100.txt
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Latency limit: 0 msec
#   Request Rate limit: 100 requests per seconds
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 20 inference requests per second
# WARNING: Pass contained only one request, so sample latency standard deviation will be infinity (UINT64_MAX).
# No valid requests recorded within time interval. Please use a larger time window.

# %%
curl -s http://triton_server:8000/v2/models/food_classifier_onnx/versions/1/stats | python -m json.tool | tee /home/jovyan/work/batch_8_results/stats_20-100.json
# Out:
# {
#     "model_stats": [
#         {
#             "name": "food_classifier_onnx",
#             "version": "1",
#             "last_inference": 1778454944990,
#             "inference_count": 1157,
#             "execution_count": 272,
#             "inference_stats": {
#                 "success": {
#                     "count": 1157,
#                     "ns": 8861934793987
#                 },
#                 "fail": {
#                     "count": 0,
#                     "ns": 0
#                 },
#                 "queue": {
#                     "count": 1157,
#                     "ns": 8564870500646
#                 },
#                 "compute_input": {
#                     "count": 1157,
#                     "ns": 1846209256
#                 },
#                 "compute_infer": {
#                     "count": 1157,
#                     "ns": 295109583170
#                 },
#                 "compute_output": {
#                     "count": 1157,
# ...

# %%
# runs inside the Jupyter container on node-serve-system
perf_analyzer -u triton_server:8000 -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 --request-rate-range 120:200:20 --async --request-distribution poisson | tee /home/jovyan/work/batch_8_results/batch_8_120-200.txt
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Latency limit: 0 msec
#   Request Rate limit: 200 requests per seconds
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 120 inference requests per second
#   Client:
#     Request count: 2257
#     Throughput: 117.608 infer/sec
#     Avg latency: 9569 usec (standard deviation 5879 usec)
#     p50 latency: 8326 usec
#     p90 latency: 13915 usec
#     p95 latency: 15680 usec
#     p99 latency: 19239 usec
#     Avg HTTP time: 9396 usec (send/recv 388 usec + response wait 9008 usec)
#   Server:
#     Inference count: 2257
#     Execution count: 2046
#     Successful request count: 2257
# ...

# %%
curl -s http://triton_server:8000/v2/models/food_classifier_onnx/versions/1/stats | python -m json.tool | tee /home/jovyan/work/batch_8_results/stats_120-200.json
# Out:
# {
#     "model_stats": [
#         {
#             "name": "food_classifier_onnx",
#             "version": "1",
#             "last_inference": 1778455196658,
#             "inference_count": 34494,
#             "execution_count": 28854,
#             "inference_stats": {
#                 "success": {
#                     "count": 34494,
#                     "ns": 16131924314640
#                 },
#                 "fail": {
#                     "count": 0,
#                     "ns": 0
#                 },
#                 "queue": {
#                     "count": 34494,
#                     "ns": 15617920442791
#                 },
#                 "compute_input": {
#                     "count": 34494,
#                     "ns": 10008126110
#                 },
#                 "compute_infer": {
#                     "count": 34494,
#                     "ns": 502143072505
#                 },
#                 "compute_output": {
# ...

# %%
# runs inside the Jupyter container on node-serve-system
perf_analyzer -u triton_server:8000 -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 --request-rate-range 220:300:20 --async --request-distribution poisson | tee /home/jovyan/work/batch_8_results/batch_8_220-300.txt
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Latency limit: 0 msec
#   Request Rate limit: 300 requests per seconds
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 220 inference requests per second
#   Client:
#     Request count: 4108
#     Avg send request rate: 231.54 infer/sec
#     [WARNING] Perf Analyzer was not able to keep up with the desired request rate. 1.17% of the requests were delayed.
#     Throughput: 216.09 infer/sec
#     Avg latency: 8619 usec (standard deviation 5250 usec)
#     p50 latency: 7676 usec
#     p90 latency: 12409 usec
#     p95 latency: 14163 usec
#     p99 latency: 22013 usec
#     Avg HTTP time: 8490 usec (send/recv 725 usec + response wait 7765 usec)
#   Server:
#     Inference count: 4108
#     Execution count: 3448
# ...

# %%
curl -s http://triton_server:8000/v2/models/food_classifier_onnx/versions/1/stats | python -m json.tool | tee /home/jovyan/work/batch_8_results/stats_220-300.json
# Out:
# {
#     "model_stats": [
#         {
#             "name": "food_classifier_onnx",
#             "version": "1",
#             "last_inference": 1778455336674,
#             "inference_count": 71064,
#             "execution_count": 58436,
#             "inference_stats": {
#                 "success": {
#                     "count": 71064,
#                     "ns": 16326844099147
#                 },
#                 "fail": {
#                     "count": 0,
#                     "ns": 0
#                 },
#                 "queue": {
#                     "count": 71064,
#                     "ns": 15689930154420
#                 },
#                 "compute_input": {
#                     "count": 71064,
#                     "ns": 16656508295
#                 },
#                 "compute_infer": {
#                     "count": 71064,
#                     "ns": 617010842192
#                 },
#                 "compute_output": {
# ...

# %%
# runs inside the Jupyter container on node-serve-system
perf_analyzer -u triton_server:8000 -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 --request-rate-range 320:400:20 --async --request-distribution poisson | tee /home/jovyan/work/batch_8_results/batch_8_320-400.txt
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Latency limit: 0 msec
#   Request Rate limit: 400 requests per seconds
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 320 inference requests per second
#   Client:
#     Request count: 6479
#     Avg send request rate: 315.84 infer/sec
#     [WARNING] Perf Analyzer was not able to keep up with the desired request rate. 3.03% of the requests were delayed.
#     Throughput: 316.71 infer/sec
#     Avg latency: 10360 usec (standard deviation 10034 usec)
#     p50 latency: 8418 usec
#     p90 latency: 14061 usec
#     p95 latency: 20677 usec
#     p99 latency: 46693 usec
#     Avg HTTP time: 10098 usec (send/recv 575 usec + response wait 9523 usec)
#   Server:
#     Inference count: 6479
#     Execution count: 4823
# ...

# %%
curl -s http://triton_server:8000/v2/models/food_classifier_onnx/versions/1/stats | python -m json.tool | tee /home/jovyan/work/batch_8_results/stats_320-400.json
# Out:
# {
#     "model_stats": [
#         {
#             "name": "food_classifier_onnx",
#             "version": "1",
#             "last_inference": 1778455590857,
#             "inference_count": 163081,
#             "execution_count": 122507,
#             "inference_stats": {
#                 "success": {
#                     "count": 163081,
#                     "ns": 16879719832900
#                 },
#                 "fail": {
#                     "count": 0,
#                     "ns": 0
#                 },
#                 "queue": {
#                     "count": 163081,
#                     "ns": 15926992407362
#                 },
#                 "compute_input": {
#                     "count": 163081,
#                     "ns": 39900346392
#                 },
#                 "compute_infer": {
#                     "count": 163081,
#                     "ns": 905871887098
#                 },
#                 "compute_output": {
# ...

# %%
# runs inside the Jupyter container on node-serve-system
perf_analyzer -u triton_server:8000 -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 --request-rate-range 420:500:20 --async --request-distribution poisson | tee /home/jovyan/work/batch_8_results/batch_8_420-500.txt
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Latency limit: 0 msec
#   Request Rate limit: 500 requests per seconds
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 420 inference requests per second
#   Client:
#     Request count: 8687
#     Avg send request rate: 430.00 infer/sec
#     [WARNING] Perf Analyzer was not able to keep up with the desired request rate. 3.15% of the requests were delayed.
#     Throughput: 423.00 infer/sec
#     Avg latency: 10567 usec (standard deviation 8598 usec)
#     p50 latency: 8974 usec
#     p90 latency: 14971 usec
#     p95 latency: 19650 usec
#     p99 latency: 43518 usec
#     Avg HTTP time: 10381 usec (send/recv 509 usec + response wait 9872 usec)
#   Server:
#     Inference count: 8687
#     Execution count: 5473
# ...

# %%
curl -s http://triton_server:8000/v2/models/food_classifier_onnx/versions/1/stats | python -m json.tool | tee /home/jovyan/work/batch_8_results/stats_420-500.json
# Out:
# {
#     "model_stats": [
#         {
#             "name": "food_classifier_onnx",
#             "version": "1",
#             "last_inference": 1778455848616,
#             "inference_count": 282302,
#             "execution_count": 191039,
#             "inference_stats": {
#                 "success": {
#                     "count": 282302,
#                     "ns": 17728563743210
#                 },
#                 "fail": {
#                     "count": 0,
#                     "ns": 0
#                 },
#                 "queue": {
#                     "count": 282302,
#                     "ns": 16331518074712
#                 },
#                 "compute_input": {
#                     "count": 282302,
#                     "ns": 79828889436
#                 },
#                 "compute_infer": {
#                     "count": 282302,
#                     "ns": 1304748203500
#                 },
#                 "compute_output": {
# ...

# %%
# runs inside the Jupyter container on node-serve-system
perf_analyzer -u triton_server:8000 -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 --request-rate-range 520:600:20 --async --request-distribution poisson | tee /home/jovyan/work/batch_8_results/batch_8_520-600.txt
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Latency limit: 0 msec
#   Request Rate limit: 600 requests per seconds
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 520 inference requests per second
# ...
#   Client:
#     Request count: 11343
#     Avg send request rate: 540.63 infer/sec
#     [WARNING] Perf Analyzer was not able to keep up with the desired request rate. 4.36% of the requests were delayed.
#     Throughput: 529.93 infer/sec
#     Avg latency: 12212 usec (standard deviation 13989 usec)
#     p50 latency: 9542 usec
#     p90 latency: 15850 usec
#     p95 latency: 29482 usec
#     p99 latency: 67929 usec
#     Avg HTTP time: 11959 usec (send/recv 604 usec + response wait 11355 usec)
#   Server:
#     Inference count: 11343
#     Execution count: 5935
# ...

# %%
curl -s http://triton_server:8000/v2/models/food_classifier_onnx/versions/1/stats | python -m json.tool | tee /home/jovyan/work/batch_8_results/stats_520-600.json
# Out:
# {
#     "model_stats": [
#         {
#             "name": "food_classifier_onnx",
#             "version": "1",
#             "last_inference": 1778456125570,
#             "inference_count": 438676,
#             "execution_count": 266754,
#             "inference_stats": {
#                 "success": {
#                     "count": 438676,
#                     "ns": 19002228932400
#                 },
#                 "fail": {
#                     "count": 0,
#                     "ns": 0
#                 },
#                 "queue": {
#                     "count": 438676,
#                     "ns": 16987631322906
#                 },
#                 "compute_input": {
#                     "count": 438676,
#                     "ns": 144217412026
#                 },
#                 "compute_infer": {
#                     "count": 438676,
#                     "ns": 1849894744782
#                 },
#                 "compute_output": {
# ...

# %%
# runs inside the Jupyter container on node-serve-system
perf_analyzer -u triton_server:8000 -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 --request-rate-range 620:700:20 --async --request-distribution poisson | tee /home/jovyan/work/batch_8_results/batch_8_620-700.txt
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Latency limit: 0 msec
#   Request Rate limit: 700 requests per seconds
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 620 inference requests per second
#   Client:
#     Request count: 14401
#     Avg send request rate: 608.61 infer/sec
#     [WARNING] Perf Analyzer was not able to keep up with the desired request rate. 6.11% of the requests were delayed.
#     Throughput: 621.49 infer/sec
#     Avg latency: 15997 usec (standard deviation 21054 usec)
#     p50 latency: 10390 usec
#     p90 latency: 30451 usec
#     p95 latency: 60392 usec
#     p99 latency: 90330 usec
#     Avg HTTP time: 15647 usec (send/recv 1036 usec + response wait 14611 usec)
#   Server:
#     Inference count: 14402
#     Execution count: 6134
# ...

# %%
curl -s http://triton_server:8000/v2/models/food_classifier_onnx/versions/1/stats | python -m json.tool | tee /home/jovyan/work/batch_8_results/stats_620-700.json

# %%
# runs inside the Jupyter container on node-serve-system
perf_analyzer -u triton_server:8000 -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 --request-rate-range 720:800:20 --async --request-distribution poisson | tee /home/jovyan/work/batch_8_results/batch_8_720-800.txt
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Latency limit: 0 msec
#   Request Rate limit: 800 requests per seconds
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 720 inference requests per second
# ...
#   Client:
#     Request count: 16511
#     Avg send request rate: 697.24 infer/sec
#     [WARNING] Perf Analyzer was not able to keep up with the desired request rate. 5.44% of the requests were delayed.
#     Throughput: 734.45 infer/sec
#     Avg latency: 18333 usec (standard deviation 25752 usec)
#     p50 latency: 11320 usec
#     p90 latency: 38053 usec
#     p95 latency: 69898 usec
#     p99 latency: 108998 usec
#     Avg HTTP time: 18038 usec (send/recv 1181 usec + response wait 16857 usec)
#   Server:
#     Inference count: 16511
#     Execution count: 5706
# ...

# %%
curl -s http://triton_server:8000/v2/models/food_classifier_onnx/versions/1/stats | python -m json.tool | tee /home/jovyan/work/batch_8_results/stats_720-800.json
# Out:
# {
#     "model_stats": [
#         {
#             "name": "food_classifier_onnx",
#             "version": "1",
#             "last_inference": 1778458766351,
#             "inference_count": 870483,
#             "execution_count": 418576,
#             "inference_stats": {
#                 "success": {
#                     "count": 870483,
#                     "ns": 23997092237585
#                 },
#                 "fail": {
#                     "count": 0,
#                     "ns": 0
#                 },
#                 "queue": {
#                     "count": 870483,
#                     "ns": 19966528155789
#                 },
#                 "compute_input": {
#                     "count": 870483,
#                     "ns": 400926587516
#                 },
#                 "compute_infer": {
#                     "count": 870483,
#                     "ns": 3581626552462
#                 },
#                 "compute_output": {
# ...

# %%
# runs inside the Jupyter container on node-serve-system
perf_analyzer -u triton_server:8000 -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 --request-rate-range 820:900:20 --async --request-distribution poisson | tee /home/jovyan/work/batch_8_results/batch_8_820-900.txt
# Out:
# *** Measurement Settings ***
#   Batch size: 1
#   Service Kind: TRITON
#   Using "time_windows" mode for stabilization
#   Stabilizing using average throughput
#   Measurement window: 5000 msec
#   Latency limit: 0 msec
#   Request Rate limit: 900 requests per seconds
#   Using poisson distribution on request generation
#   Using asynchronous calls for inference
#
# Request Rate: 820 inference requests per second
#   Client:
#     Request count: 17295
#     Avg send request rate: 865.95 infer/sec
#     [WARNING] Perf Analyzer was not able to keep up with the desired request rate. 3.80% of the requests were delayed.
#     Throughput: 825.81 infer/sec
#     Avg latency: 16220 usec (standard deviation 15459 usec)
#     p50 latency: 12921 usec
#     p90 latency: 22442 usec
#     p95 latency: 41329 usec
#     p99 latency: 74945 usec
#     Avg HTTP time: 16022 usec (send/recv 786 usec + response wait 15236 usec)
#   Server:
#     Inference count: 17296
#     Execution count: 4802
# ...

# %%
curl -s http://triton_server:8000/v2/models/food_classifier_onnx/versions/1/stats | python -m json.tool | tee /home/jovyan/work/batch_8_results/stats_820-900.json

# %%
# runs inside the Jupyter container on node-serve-system
perf_analyzer -u triton_server:8000 -m food_classifier_onnx -b 1 --shape IMAGE:3,224,224 --request-rate-range 920:1000:20 --async --request-distribution poisson | tee /home/jovyan/work/batch_8_results/batch_8_920-1000.txt

# %%
curl -s http://triton_server:8000/v2/models/food_classifier_onnx/versions/1/stats | python -m json.tool | tee /home/jovyan/work/batch_8_results/stats_920-1000.json
# Out:
# Expecting value: line 1 column 1 (char 0)
# : 1
